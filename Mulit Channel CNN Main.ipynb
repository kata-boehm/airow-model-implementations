# %% [markdown]
# # 1D CNN for Heart Rate Interval Segmentation
#
# **Master's Thesis Implementation**
#
# This notebook implements a 1D Convolutional Neural Network for detecting workout interval boundaries from heart rate data.
#
# Run all cells from top to bottom.

# %% [markdown]
# ## 1. Imports and Setup

# %%
import numpy as np
import pandas as pd
import os
from typing import Dict, List, Tuple
from dataclasses import dataclass
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.signal import find_peaks
from scipy.ndimage import gaussian_filter1d

# TensorFlow imports
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint

import warnings
warnings.filterwarnings('ignore')


from multi_channel_cnn import (
    MultiChannelConfig,
    create_hr_features_grouped,
    prepare_multichannel_segments,
    train_multichannel_cnn,
    predict_multichannel_cnn
)

# Set style
sns.set_style("whitegrid")
plt.rcParams['figure.figsize'] = (14, 8)

# Reproducibility
RANDOM_SEED = 123
import random  # ADD THIS LINE
random.seed(RANDOM_SEED)  # ADD THIS LINE
np.random.seed(RANDOM_SEED)
tf.random.set_seed(RANDOM_SEED)
os.environ['PYTHONHASHSEED'] = str(RANDOM_SEED)  # ADD THIS LINE

print(f"✓ Imports complete")
print(f"✓ TensorFlow version: {tf.__version__}")
print(f"✓ Random seed: {RANDOM_SEED}")
# Out:
# ✓ Imports complete
# ✓ TensorFlow version: 2.20.0
# ✓ Random seed: 123

# %% [markdown]
# ## 2. Configuration

# %%
@dataclass
class Config:
    """Configuration for the segmentation pipeline."""
    random_seed: int = 123
    
    # Feature engineering
    short_window: int = 30
    medium_window: int = 60
    long_window: int = 120
    
    # CNN specific
    segment_length: int = 300  # 5 minutes
    segment_overlap: int = 150  # 50% overlap
    
    # Post-processing
    peak_distance: int = 30
    peak_prominence: float = 0.1
    smooth_sigma: float = 5.0

# Single config for helper functions (peak detection, evaluation)
CONFIG = Config()

# Multi-channel CNN config (extends base config with feature groups)
CONFIG_MC = MultiChannelConfig(
    random_seed=123,
    short_window=30,
    medium_window=60,
    long_window=120,
    segment_length=300,
    segment_overlap=150,
    peak_distance=30,
    peak_prominence=0.1,
    smooth_sigma=5.0
)

print(f"✓ Configuration set")
print(f"✓ Multi-channel CNN: {len(CONFIG_MC.feature_groups)} feature groups")
for group_name in CONFIG_MC.feature_groups.keys():
    print(f"    • {group_name}")
# Out:
# ✓ Configuration set
# ✓ Multi-channel CNN: 5 feature groups
#     • raw_and_smooth
#     • trends
#     • baseline_deviations
#     • rolling_stats
#     • temporal_context

# %% [markdown]
# ## 3. Your Data Configuration

# %%
athletes = {
    "Athlete12": {
        "sport": "rowing", "ftp": 230,
        "fit_dir": "AthleteDataCoding/Athlete12/OGs",
        "label_dir": "AthleteDataCoding/Athlete12/GTs",
        "allowed_files": {
            "10536403349_5006_row.fit", "10543962115_10006_row.fit", "10551999765_10006_row.fit",
            "10652950510_Btchen_fahren.fit", "10674304801_Btchen_fahren_in_Etappen_3.fit",
            "10694767945_Btchen_fahren_.fit", "10809067165_3007_row.fit", "11636429453_4558_row.fit",
            "11783093951_4x2000_sub8.fit", "11791568584_.fit", "11808467517_.fit",
            "11838948742_3006_row.fit", "11846980624_Platt_.fit", "11855866225_In_den_Seilen.fit",
            "11864381887_Catwalk_.fit", "11912062341_500er_in_grau.fit", "11962243206_Wundmanagement.fit",
            "11971395278_Use_it_or_lose_it.fit", "11987690514_Besser_als_Nix.fit",
            "11994450315_Airobics.fit", "12036692734_Exhausted.fit", "12069656901_Schwitzen_im_Sitzen.fit",
            "12501679452_Zustand_nach_Xtem_Atemwegsinfekt.fit", "12806981726_Row_Stretch__Stabi.fit",
            "12846436186_Synchronflug.fit", "12927701413_I_have_no_idea_when_Ill_be_back_in_serious_training_routine_but_at_least_we_have_a_kitchen.fit",
            "12951604563_DienstSport.fit", "13010348229_1h_w_4x1_intensity.fit", "13039020832_Analytiker.fit",
            "13280559542_Warm_up_rowing.fit", "13300350440_W_Up.fit", "13363035398_SGAktiv.fit",
            "13582048984_W_Up.fit", "13583093636_Afterburner_.fit", "13601462878_Zehnbauer.fit",
            "13609970768_Uffwrme.fit", "13610691264_1x_Crescendo.fit", "13618782252_3x5.fit",
            "13643807487_Nachfitten.fit", "13662882990_Heldentod.fit", "13672121049_Base_Miles.fit",
            "13688068283_Luftpresser.fit", "13918354210_W_Upen.fit", "13957096402_Technik.fit",
            "13971240869_A_ella_le_gusta.fit", "13974345688_Nochmaaaal.fit", "13983533934_Technik__30er.fit",
            "14001095362_Wer_will_der_kann_.fit", "14038989670__Hyperthermie_.fit", "14077735636_Base.fit",
            "14089880174_Zn_IKEA.fit", "14114545767_Dampfnudel.fit", "14125110656_Vallah_isch_balla.fit",
            "14135321532_Pimp_my_ride.fit", "14156450361_On_a_mission.fit", "14174927764_Dunstabzugshaubenselfie.fit",
            "14182817844_The_Emptiness_Machine.fit", "14260930602_3x1010_SubThr.fit",
            "14313279747_Vernunft_verliert_.fit", "14374019349_Uff.fit", "14396237986_4659_row.fit"
        },
    },
    "Athlete2": {
        "sport": "biking", "ftp": 341,
        "fit_dir": "AthleteDataCoding/Athlete2/OGs",
        "label_dir": "AthleteDataCoding/Athlete2/GTs",
        "allowed_files": "all"
    },
    "AthletesSpecialBike": {
        "sport": "biking", "ftp": None, "fit_dir": None,
        "label_dir": "AthleteDataCoding/SpecialBike_Labeled_NotSorted_Biking/GTs",
        "allowed_files": "all"
    },
    "AthletesSpecialRowing": {
        "sport": "rowing", "ftp": None, "fit_dir": None,
        "label_dir": "AthleteDataCoding/SpecialBike_Labeled_NotSorted_Rowing/GTs",
        "allowed_files": "all"
    }
}

test_sessions = [
    ("Athlete2", "13363782092_Zwift__Aerobic_Mixup_in_New_York"),
    ("Athlete2", "i65696340_Zwift__LC16_Lactate_Clearance_Over_Under_in_Watopia"),
    ("Athlete12", "13601462878_Zehnbauer"), ("Athlete12", "12036692734_Exhausted"),
    ("Athlete12", "12846436186_Synchronflug"), ("Athlete12", "11962243206_Wundmanagement"),
    ("Athlete12", "13688068283_Luftpresser"), ("Athlete12", "11783093951_4x2000_sub8"),
    ("Athlete12", "13983533934_Technik__30er"), ("Athlete12", "11846980624_Platt_"),
    ("Athlete12", "14125110656_Vallah_isch_balla"), ("Athlete12", "12069656901_Schwitzen_im_Sitzen"),
    ("Athlete12", "12989160676_Wohnzimmerromantik"), ("Athlete12", "14089880174_Zn_IKEA"),
    ("AthletesSpecialBike", "6697827529_Zwift__VO2max_1h110"),
    ("AthletesSpecialBike", "14691322045_Zwift__3x12min_3030_4x2min_Vo2Max_on_Road_to_Sky_in_Watopia"),
    ("AthletesSpecialBike", "10283878603_Zwift__HIT__HIT_EB_5x3_min_in_Watopia"),
    ("AthletesSpecialBike", "13557212506_Zwift__HIT__HIT_EB_7x2_min_VLamax_Pusher_in_Watopia"),
    ("AthletesSpecialRowing", "14612015090_3x_6x_3030")
]

print(f"✓ Data config loaded - {len(test_sessions)} test sessions")
# Out:
# ✓ Data config loaded - 19 test sessions

# %% [markdown]
# ## 4. Helper Functions
#
# Feature engineering, post-processing, and evaluation functions.

# %%
def create_hr_features(df: pd.DataFrame, config: Config) -> pd.DataFrame:
    """Create rich feature set from heart rate time series."""
    features = pd.DataFrame(index=df.index)
    hr = df['heart_rate'].values
    
    # Smoothed HR
    features['hr_raw'] = hr
    features['hr_smooth_short'] = df['heart_rate'].rolling(window=config.short_window, center=True, min_periods=1).mean()
    features['hr_smooth_medium'] = df['heart_rate'].rolling(window=config.medium_window, center=True, min_periods=1).mean()
    features['hr_smooth_long'] = df['heart_rate'].rolling(window=config.long_window, center=True, min_periods=1).mean()
    
    # Derivatives
    features['hr_diff_1s'] = df['heart_rate'].diff(1)
    features['hr_diff_5s'] = df['heart_rate'].diff(5)
    features['hr_diff_10s'] = df['heart_rate'].diff(10)
    features['hr_diff_30s'] = df['heart_rate'].diff(30)
    features['hr_accel'] = features['hr_diff_1s'].diff(1)
    
    # Rolling statistics
    features['hr_std_short'] = df['heart_rate'].rolling(window=config.short_window, center=True, min_periods=1).std()
    features['hr_min_short'] = df['heart_rate'].rolling(window=config.short_window, center=True, min_periods=1).min()
    features['hr_max_short'] = df['heart_rate'].rolling(window=config.short_window, center=True, min_periods=1).max()
    features['hr_range_short'] = features['hr_max_short'] - features['hr_min_short']
    features['hr_std_medium'] = df['heart_rate'].rolling(window=config.medium_window, center=True, min_periods=1).std()
    features['hr_min_medium'] = df['heart_rate'].rolling(window=config.medium_window, center=True, min_periods=1).min()
    features['hr_max_medium'] = df['heart_rate'].rolling(window=config.medium_window, center=True, min_periods=1).max()
    
    # Relative features
    features['hr_vs_short_baseline'] = hr - features['hr_smooth_short']
    features['hr_vs_medium_baseline'] = hr - features['hr_smooth_medium']
    features['hr_vs_long_baseline'] = hr - features['hr_smooth_long']
    
    # Trends
    features['hr_increasing'] = (features['hr_diff_10s'] > 0).astype(int)
    features['hr_decreasing'] = (features['hr_diff_10s'] < 0).astype(int)
    features['hr_stable'] = (features['hr_diff_10s'].abs() < 1).astype(int)
    
    # Lagged
    features['hr_lag_30s'] = df['heart_rate'].shift(30)
    features['hr_lag_60s'] = df['heart_rate'].shift(60)
    features['hr_lag_90s'] = df['heart_rate'].shift(90)
    features['hr_lead_30s'] = df['heart_rate'].shift(-30)
    features['hr_lead_60s'] = df['heart_rate'].shift(-60)
    features['hr_change_past_to_future'] = features['hr_lead_60s'] - features['hr_lag_60s']
    
    # Clean
    features = features.replace([np.inf, -np.inf], np.nan).ffill().bfill().fillna(0)
    for col in features.columns:
        if features[col].std() > 0:
            q99, q01 = features[col].quantile(0.99), features[col].quantile(0.01)
            features[col] = features[col].clip(q01, q99)
    return features


def detect_peaks_with_constraint(probabilities: np.ndarray, n_expected_intervals: int, config: Config) -> np.ndarray:
    """Detect peaks with interval count constraint."""
    probs_smooth = gaussian_filter1d(probabilities, sigma=config.smooth_sigma)
    forced_peaks, n_remaining = [0], n_expected_intervals - 1
    peaks, _ = find_peaks(probs_smooth[config.peak_distance:], distance=config.peak_distance, prominence=config.peak_prominence)
    peaks = peaks + config.peak_distance
    if len(peaks) >= n_remaining:
        peak_heights = probs_smooth[peaks]
        peaks = peaks[np.argsort(peak_heights)[-n_remaining:]]
    return np.sort(np.concatenate([forced_peaks, peaks]))


def evaluate_with_tolerance_asymmetric(y_true, y_pred, tolerance_before=10, tolerance_after=10):
    """Evaluate with asymmetric tolerance."""
    true_b, pred_b = np.where(y_true == 1)[0], np.where(y_pred == 1)[0]
    matched_p = sum(1 for p in pred_b if any(-tolerance_before <= p - t <= tolerance_after for t in true_b))
    matched_t = sum(1 for t in true_b if any(-tolerance_before <= p - t <= tolerance_after for p in pred_b))
    precision = matched_p / len(pred_b) if len(pred_b) > 0 else 0
    recall = matched_t / len(true_b) if len(true_b) > 0 else 0
    f_beta = (5 * precision * recall) / (4 * precision + recall) if (4 * precision + recall) > 0 else 0
    errors = [np.abs(true_b - p).min() for p in pred_b]
    return {'precision': precision, 'recall': recall, 'f_beta': f_beta, 'n_true': len(true_b), 
            'n_pred': len(pred_b), 'mean_error_sec': np.mean(errors) if errors else 0}

print("✓ Helper functions defined")
# Out:
# ✓ Helper functions defined

# %% [markdown]
# ## 5. Load Data

# %%
def load_all_sessions(athletes):
    session_data = {}
    for athlete, meta in athletes.items():
        label_dir, allowed = meta["label_dir"], meta["allowed_files"]
        csv_files = sorted([f for f in os.listdir(label_dir) if f.endswith("_with_manual_labels.csv")] 
                          if allowed == "all" else [f.replace(".fit", "_with_manual_labels.csv") for f in allowed])
        for filename in csv_files:
            file_path = os.path.join(label_dir, filename)
            if not os.path.exists(file_path): continue
            try:
                df = pd.read_csv(file_path)
                df['timestamp'] = pd.to_datetime(df['timestamp'], utc=True)
                df = df.sort_values('timestamp').drop_duplicates(subset='timestamp').reset_index(drop=True)
                df['manual_timestamp_numerical'] = df['Manual_Timestamps'].astype(str).str.lower().isin(['true', '1']).astype(int)
                df.loc[0, 'manual_timestamp_numerical'] = 1
                df['heart_rate'] = df['heart_rate'].ffill().bfill()
                if 'power' in df.columns: df['power'] = df['power'].ffill().bfill().fillna(0)
                session_name = filename.replace("_with_manual_labels.csv", "")
                session_data[(athlete, session_name)] = df
                print(f"✓ {athlete} - {session_name[:40]}")
            except Exception as e: print(f"❌ {filename}: {e}")
    return session_data

print("\n📂 Loading sessions...")
hr_session_data = load_all_sessions(athletes)
print(f"\n✓ Loaded {len(hr_session_data)} sessions")
# Out:
# 📂 Loading sessions...
# ✓ Athlete12 - 10536403349_5006_row
# ✓ Athlete12 - 10543962115_10006_row
# ✓ Athlete12 - 10551999765_10006_row
# ✓ Athlete12 - 10652950510_Btchen_fahren
# ✓ Athlete12 - 10674304801_Btchen_fahren_in_Etappen_3
# ✓ Athlete12 - 10694767945_Btchen_fahren_
# ✓ Athlete12 - 10809067165_3007_row
# ✓ Athlete12 - 11636429453_4558_row
# ✓ Athlete12 - 11783093951_4x2000_sub8
# ✓ Athlete12 - 11791568584_
# ✓ Athlete12 - 11808467517_
# ✓ Athlete12 - 11838948742_3006_row
# ✓ Athlete12 - 11846980624_Platt_
# ✓ Athlete12 - 11855866225_In_den_Seilen
# ✓ Athlete12 - 11864381887_Catwalk_
# ✓ Athlete12 - 11912062341_500er_in_grau
# ✓ Athlete12 - 11962243206_Wundmanagement
# ✓ Athlete12 - 11971395278_Use_it_or_lose_it
# ✓ Athlete12 - 11987690514_Besser_als_Nix
# ✓ Athlete12 - 11994450315_Airobics
# ✓ Athlete12 - 12036692734_Exhausted
# ✓ Athlete12 - 12069656901_Schwitzen_im_Sitzen
# ✓ Athlete12 - 12501679452_Zustand_nach_Xtem_Atemwegsin
# ✓ Athlete12 - 12806981726_Row_Stretch__Stabi
# ✓ Athlete12 - 12846436186_Synchronflug
# ✓ Athlete12 - 12927701413_I_have_no_idea_when_Ill_be_b
# ✓ Athlete12 - 12951604563_DienstSport
# ✓ Athlete12 - 13010348229_1h_w_4x1_intensity
# ✓ Athlete12 - 13039020832_Analytiker
# ✓ Athlete12 - 13280559542_Warm_up_rowing
# ✓ Athlete12 - 13300350440_W_Up
# ✓ Athlete12 - 13363035398_SGAktiv
# ✓ Athlete12 - 13582048984_W_Up
# ✓ Athlete12 - 13583093636_Afterburner_
# ✓ Athlete12 - 13601462878_Zehnbauer
# ✓ Athlete12 - 13609970768_Uffwrme
# ✓ Athlete12 - 13610691264_1x_Crescendo
# ✓ Athlete12 - 13618782252_3x5
# ✓ Athlete12 - 13643807487_Nachfitten
# ✓ Athlete12 - 13662882990_Heldentod
# ✓ Athlete12 - 13672121049_Base_Miles
# ✓ Athlete12 - 13688068283_Luftpresser
# ✓ Athlete12 - 13918354210_W_Upen
# ✓ Athlete12 - 13957096402_Technik
# ✓ Athlete12 - 13971240869_A_ella_le_gusta
# ✓ Athlete12 - 13974345688_Nochmaaaal
# ✓ Athlete12 - 13983533934_Technik__30er
# ✓ Athlete12 - 14001095362_Wer_will_der_kann_
# ✓ Athlete12 - 14038989670__Hyperthermie_
# ✓ Athlete12 - 14077735636_Base
# ✓ Athlete12 - 14089880174_Zn_IKEA
# ✓ Athlete12 - 14114545767_Dampfnudel
# ✓ Athlete12 - 14125110656_Vallah_isch_balla
# ✓ Athlete12 - 14135321532_Pimp_my_ride
# ✓ Athlete12 - 14156450361_On_a_mission
# ✓ Athlete12 - 14174927764_Dunstabzugshaubenselfie
# ✓ Athlete12 - 14182817844_The_Emptiness_Machine
# ✓ Athlete12 - 14260930602_3x1010_SubThr
# ✓ Athlete12 - 14313279747_Vernunft_verliert_
# ✓ Athlete12 - 14374019349_Uff
# ✓ Athlete12 - 14396237986_4659_row
# ✓ Athlete2 - 13363782092_Zwift__Aerobic_Mixup_in_New_
# ✓ Athlete2 - 13439251418_Zwift__TNR04_Endurance_NonRo
# ✓ Athlete2 - 13492084557_EH11_Endurance_Steady_Ride
# ✓ Athlete2 - 13555004697_Zwift__LT08_Lactate_Threshol
# ✓ Athlete2 - i65696340_Zwift__LC16_Lactate_Clearance_
# ✓ Athlete2 - i65940230_Zwift__LT14_Lactate_Threshold_
# ✓ Athlete2 - i68225040_Zwift__VE4_VO2Max_30_Second__1
# ✓ Athlete2 - i69340324_Zwift__V08_VO2Max_4_Minutes_Co
# ✓ Athlete2 - i74545686_Zwift__V11_VO2Max_Hard_Finish_
# ✓ Athlete2 - i77791045_Zwift__R06_Recovery_Easy_Ride_
# ✓ AthletesSpecialBike - 10283878603_Zwift__HIT__HIT_EB_5x3_min_i
# ✓ AthletesSpecialBike - 10410929216_Zwift__10x_3030__8x_4040__4x
# ✓ AthletesSpecialBike - 10577414184_Zwift__HIT__HIT_LI_4x8_min_1
# ✓ AthletesSpecialBike - 12376609525_Zwift__HIT__HIT_anaerob_6x30
# ✓ AthletesSpecialBike - 12493527326_MyWhoosh__HIT__HIT_EB_4x8_mi
# ✓ AthletesSpecialBike - 13064607574_Zwift__HIT__HIT_EB_5x4_min_i
# ✓ AthletesSpecialBike - 13185915461_Zwift__HIT__HIT_LI_4x8_min_1
# ✓ AthletesSpecialBike - 13432733040_Zwift__HIT__HIT_EB_5x5_min_i
# ✓ AthletesSpecialBike - 13557212506_Zwift__HIT__HIT_EB_7x2_min_V
# ✓ AthletesSpecialBike - 14691322045_Zwift__3x12min_3030_4x2min_V
# ✓ AthletesSpecialBike - 14752182092_Zwift__3x12min_3030_on_Road_
# ✓ AthletesSpecialBike - 14898721683_Zwift__3x12min_3030_4x2_Vo2M
# ✓ AthletesSpecialBike - 15055098162_MyWhoosh__3x8_3030_Vo2max_12
# ✓ AthletesSpecialBike - 6697827529_Zwift__VO2max_1h110
# ✓ AthletesSpecialBike - 8465294644_Zwift__HIT__IE_3x10x4020_in_W
# ✓ AthletesSpecialBike - i79840180_AP08_Anaerobic_Power_60_Second
# ✓ AthletesSpecialBike - i90773880_Zwift__9x_10_3030
# ✓ AthletesSpecialBike - i93605941_Zwift__VO2_Short_Intervals_in_
# ✓ AthletesSpecialBike - i93606478_Zwift__3030_in_Watopia
# ✓ AthletesSpecialBike - i93606486_Zwift__PBA_HIT__HITdec_6x5min_
# ✓ AthletesSpecialRowing - 14612015090_3x_6x_3030
# ✓ AthletesSpecialRowing - 15097759724_3x_8_de_3030
#
# ✓ Loaded 93 sessions

# %% [markdown]
# ## 6. Prepare Features and Split Data

# %%
train_sessions, test_sessions_data = [], []
for (athlete, session), df in hr_session_data.items():
    # Use new grouped feature creation
    features_df, grouped_features = create_hr_features_grouped(df, CONFIG_MC)
    X, y = features_df.values, df['manual_timestamp_numerical'].values
    if np.any(np.isnan(X)) or np.any(np.isinf(X)): continue

    session_info = {
        'athlete': athlete,
        'session': session,
        'X': X,  # Keep this for backward compatibility
        'y': y,
        'n_intervals': y.sum(),
        'duration_sec': len(y),
        'feature_names': features_df.columns.tolist(),
        'df': df,
        'grouped_features': grouped_features  # NEW: Store grouped features
    }
    (test_sessions_data if (athlete, session) in test_sessions else train_sessions).append(session_info)

# Scaling (same as before)
scaler = StandardScaler().fit(np.vstack([s['X'] for s in train_sessions]))
for s in train_sessions + test_sessions_data: s['X'] = scaler.transform(s['X'])

print(f"✓ Train: {len(train_sessions)}, Test: {len(test_sessions_data)}, Features: {train_sessions[0]['X'].shape[1]}")
print(f"✓ Grouped features stored in each session")
# Out:
# ✓ Train: 75, Test: 18, Features: 28
# ✓ Grouped features stored in each session

# %% [markdown]
# ## 7. Prepare CNN Segments

# %%
def prepare_cnn_segments(sessions, seg_len=300, overlap=150):
    all_X, all_y, stride = [], [], seg_len - overlap
    for s in sessions:
        for i in range((len(s['X']) - seg_len) // stride + 1):
            start, end = i * stride, i * stride + seg_len
            if end <= len(s['X']): all_X.append(s['X'][start:end]); all_y.append(s['y'][start:end])
    return np.array(all_X), np.array(all_y)

# Prepare multi-channel segments
print("Preparing multi-channel segments...")
X_train_mc, y_train_mc = prepare_multichannel_segments(train_sessions, CONFIG_MC)

print(f"\n✓ Multi-channel training data:")
for group_name, X_group in X_train_mc.items():
    print(f"  {group_name:25s}: {X_group.shape}")
print(f"  Labels: {y_train_mc.shape}")
print(f"  Positive: {y_train_mc.sum():,}/{y_train_mc.size:,} ({y_train_mc.sum()/y_train_mc.size*100:.3f}%)")
# Out:
# Preparing multi-channel segments...
#
# ✓ Multi-channel training data:
#   raw_and_smooth           : (1760, 300, 4)
#   trends                   : (1760, 300, 8)
#   baseline_deviations      : (1760, 300, 3)
#   rolling_stats            : (1760, 300, 7)
#   temporal_context         : (1760, 300, 6)
#   Labels: (1760, 300)
#   Positive: 2,756/528,000 (0.522%)

# %% [markdown]
# ## 8. Build and Train 1D CNN

# %%
print("\n🏋️ Training multi-channel CNN...")
model_mc, history_mc = train_multichannel_cnn(X_train_mc, y_train_mc, CONFIG_MC)
print("✓ Multi-channel CNN trained!")
# Out:
# 🏋️ Training multi-channel CNN...
# Positive weight: 190.58
#
# Input shapes per group:
#   raw_and_smooth           : (300, 4)
#   trends                   : (300, 8)
#   baseline_deviations      : (300, 3)
#   rolling_stats            : (300, 7)
#   temporal_context         : (300, 6)
#
# 📊 Model summary:
# Total parameters: 856,273
#
# 🏋️ Training multi-channel CNN...
# Epoch 1/25
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 61s 761ms/step - accuracy: 0.7273 - loss: 0.9194 - val_accuracy: 0.9684 - val_loss: 23.9076 - learning_rate: 0.0010
# Epoch 2/25
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 32s 669ms/step - accuracy: 0.8315 - loss: 0.7288 - val_accuracy: 0.7981 - val_loss: 13.1918 - learning_rate: 0.0010
# Epoch 3/25
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 35s 741ms/step - accuracy: 0.8439 - loss: 0.6785 - val_accuracy: 0.7655 - val_loss: 6.3856 - learning_rate: 0.0010
# Epoch 4/25
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 46s 833ms/step - accuracy: 0.8604 - loss: 0.6219 - val_accuracy: 0.8073 - val_loss: 4.4582 - learning_rate: 0.0010
# Epoch 5/25
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 43s 913ms/step - accuracy: 0.8627 - loss: 0.5956 - val_accuracy: 0.8242 - val_loss: 3.2393 - learning_rate: 0.0010
# Epoch 6/25
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 27s 581ms/step - accuracy: 0.8673 - loss: 0.5680 - val_accuracy: 0.8394 - val_loss: 2.8391 - learning_rate: 0.0010
# Epoch 7/25
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 29s 616ms/step - accuracy: 0.8717 - loss: 0.5372 - val_accuracy: 0.6786 - val_loss: 1.9988 - learning_rate: 0.0010
# Epoch 8/25
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 28s 606ms/step - accuracy: 0.8748 - loss: 0.5096 - val_accuracy: 0.6526 - val_loss: 2.4996 - learning_rate: 0.0010
# Epoch 9/25
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 24s 503ms/step - accuracy: 0.8632 - loss: 0.5189 - val_accuracy: 0.9786 - val_loss: 12.3564 - learning_rate: 0.0010
# Epoch 10/25
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 21s 454ms/step - accuracy: 0.8722 - loss: 0.5047 - val_accuracy: 0.8512 - val_loss: 3.0669 - learning_rate: 0.0010
# Epoch 11/25
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 23s 487ms/step - accuracy: 0.8756 - loss: 0.4629 - val_accuracy: 0.7531 - val_loss: 3.0811 - learning_rate: 0.0010
# Epoch 12/25
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 22s 470ms/step - accuracy: 0.8838 - loss: 0.4329 - val_accuracy: 0.9028 - val_loss: 4.5216 - learning_rate: 0.0010
# Epoch 13/25
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 24s 506ms/step - accuracy: 0.8900 - loss: 0.3934 - val_accuracy: 0.7386 - val_loss: 2.5234 - learning_rate: 5.0000e-04
# Epoch 14/25
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 24s 501ms/step - accuracy: 0.8988 - loss: 0.3723 - val_accuracy: 0.7666 - val_loss: 2.7316 - learning_rate: 5.0000e-04
# Epoch 15/25
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 26s 556ms/step - accuracy: 0.9015 - loss: 0.3569 - val_accuracy: 0.8550 - val_loss: 4.3162 - learning_rate: 5.0000e-04
# Epoch 16/25
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 39s 516ms/step - accuracy: 0.9087 - loss: 0.3356 - val_accuracy: 0.8174 - val_loss: 3.6768 - learning_rate: 5.0000e-04
# Epoch 17/25
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 25s 534ms/step - accuracy: 0.9105 - loss: 0.3262 - val_accuracy: 0.8266 - val_loss: 3.5918 - learning_rate: 5.0000e-04
# ✓ Multi-channel CNN trained!

# %%
import matplotlib.pyplot as plt

fig, axes = plt.subplots(1, 2, figsize=(14, 4))

axes[0].plot(history_mc.history['loss'], label='Train Loss', linewidth=2)
axes[0].plot(history_mc.history['val_loss'], label='Val Loss', linewidth=2, color='red')
axes[0].axhline(y=3, color='orange', linestyle='--', label='Trouble Zone')
axes[0].set_xlabel('Epoch')
axes[0].set_ylabel('Loss')
axes[0].set_title('Training vs Validation Loss (OVERFITTING!)')
axes[0].legend()
axes[0].grid(True, alpha=0.3)

axes[1].plot(history_mc.history['accuracy'], label='Train Acc', linewidth=2)
axes[1].plot(history_mc.history['val_accuracy'], label='Val Acc', linewidth=2)
axes[1].set_xlabel('Epoch')
axes[1].set_ylabel('Accuracy')
axes[1].set_title('Training vs Validation Accuracy')
axes[1].legend()
axes[1].grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 9. Evaluate on Test Sessions

# %%
print("\n📊 Evaluating on test sessions...")
results_mc = []

for s in test_sessions_data:
    # Use multi-channel prediction
    proba = predict_multichannel_cnn(model_mc, s, CONFIG_MC)

    # Peak detection (same as before)
    peaks = detect_peaks_with_constraint(proba, s['n_intervals'], CONFIG)
    pred = np.zeros(len(proba), dtype=int)
    pred[peaks] = 1

    # Evaluation (same as before)
    m = evaluate_with_tolerance_asymmetric(s['y'], pred, 10, 10)
    m.update({
        'athlete': s['athlete'],
        'session': s['session'],
        'df': s['df'],
        'y_true': s['y'],
        'y_pred': pred,
        'probabilities': proba  # Store for visualization
    })
    results_mc.append(m)

    print(f"{m['athlete']:12s} | {m['session'][:30]:30s} | "
          f"F={m['f_beta']:.3f} P={m['precision']:.3f} R={m['recall']:.3f} E={m['mean_error_sec']:.1f}s")

# Calculate averages
avg_mc = {k: np.mean([r[k] for r in results_mc]) for k in ['f_beta', 'precision', 'recall', 'mean_error_sec']}
print(f"\n📊 Multi-Channel CNN: F_beta={avg_mc['f_beta']:.3f}, P={avg_mc['precision']:.3f}, "
      f"R={avg_mc['recall']:.3f}, Error={avg_mc['mean_error_sec']:.1f}s")
# Out:
# 📊 Evaluating on test sessions...
# Athlete12    | 11783093951_4x2000_sub8        | F=0.889 P=0.889 R=0.889 E=5.3s
# Athlete12    | 11846980624_Platt_             | F=0.700 P=0.700 R=0.700 E=23.2s
# Athlete12    | 11962243206_Wundmanagement     | F=0.833 P=0.833 R=0.833 E=48.3s
# Athlete12    | 12036692734_Exhausted          | F=0.556 P=0.556 R=0.556 E=45.2s
# Athlete12    | 12069656901_Schwitzen_im_Sitze | F=0.429 P=0.429 R=0.429 E=69.1s
# Athlete12    | 12846436186_Synchronflug       | F=0.667 P=0.667 R=0.667 E=141.0s
# Athlete12    | 13601462878_Zehnbauer          | F=0.667 P=0.667 R=0.667 E=67.6s
# Athlete12    | 13688068283_Luftpresser        | F=0.727 P=0.727 R=0.727 E=19.1s
# Athlete12    | 13983533934_Technik__30er      | F=0.545 P=0.545 R=0.545 E=20.4s
# Athlete12    | 14089880174_Zn_IKEA            | F=0.625 P=0.625 R=0.625 E=92.2s
# Athlete12    | 14125110656_Vallah_isch_balla  | F=0.818 P=0.818 R=0.818 E=60.6s
# Athlete2     | 13363782092_Zwift__Aerobic_Mix | F=0.600 P=0.600 R=0.600 E=43.2s
# Athlete2     | i65696340_Zwift__LC16_Lactate_ | F=0.300 P=0.300 R=0.300 E=192.5s
# AthletesSpecialBike | 10283878603_Zwift__HIT__HIT_EB | F=0.625 P=0.625 R=0.625 E=69.4s
# AthletesSpecialBike | 13557212506_Zwift__HIT__HIT_EB | F=0.599 P=0.556 R=0.611 E=20.9s
# AthletesSpecialBike | 14691322045_Zwift__3x12min_303 | F=0.494 P=0.520 R=0.488 E=95.2s
# AthletesSpecialBike | 6697827529_Zwift__VO2max_1h110 | F=0.688 P=0.688 R=0.688 E=14.9s
# AthletesSpecialRowing | 14612015090_3x_6x_3030         | F=0.613 P=0.651 R=0.604 E=31.1s
#
# 📊 Multi-Channel CNN: F_beta=0.632, P=0.633, R=0.632, Error=58.9s

# %%
# Create subplots for all test sessions
n_sessions = len(results_mc)  # Changed from results to results_mc
fig, axes = plt.subplots(n_sessions, 1, figsize=(20, 4*n_sessions))

# Handle case where there's only one session
if n_sessions == 1:
    axes = [axes]

for idx, result in enumerate(results_mc):  # Changed from results to results_mc
    df = result['df']
    y_true = result['y_true']
    y_pred = result['y_pred']

    hr_values = df['heart_rate'].values

    # Create twin axis for power
    ax1 = axes[idx]
    ax2 = ax1.twinx()

    # Plot heart rate on left axis (RED)
    ax1.plot(hr_values, label='Heart Rate', color='red', alpha=0.7, linewidth=2)

    # Plot power on right axis (BLUE)
    if 'power' in df.columns:
        power_values = df['power'].values
        ax2.plot(power_values, label='Power', color='blue', alpha=0.6, linewidth=2)
        ax2.set_ylabel('Power (W)', fontsize=10, color='blue')
        ax2.tick_params(axis='y', labelcolor='blue')

    # Get change points
    gt_cps = np.where(y_true == 1)[0]
    pred_cps = np.where(y_pred == 1)[0]

    # Mark ground truth change points with GREEN vertical dotted lines
    for cp in gt_cps:
        if cp < len(hr_values):
            ax1.axvline(x=cp, color='green', linestyle=':', linewidth=2.5,
                       alpha=0.8, zorder=4, label='Ground Truth' if cp == gt_cps[0] else '')

    # Mark predicted change points with YELLOW X
    for cp in pred_cps:
        if cp < len(hr_values):
            ax1.scatter(cp, hr_values[cp], marker='x', s=250, color='yellow',
                       linewidths=4, zorder=5, label='Predicted' if cp == pred_cps[0] else '')

    # Set title with session info and metrics
    ax1.set_title(
        f"{result['athlete']} | {result['session']}\n"
        f"GT: {result['n_true']} CPs | Pred: {result['n_pred']} CPs | "
        f"P={result['precision']:.2f}, R={result['recall']:.2f}, F_beta={result['f_beta']:.2f}",
        fontsize=10, pad=10
    )

    ax1.set_ylabel('Heart Rate (bpm)', fontsize=10, color='red')
    ax1.set_xlabel('Time (seconds)', fontsize=10)
    ax1.tick_params(axis='y', labelcolor='red')
    ax1.grid(True, alpha=0.3)

    # Combine legends from both axes
    lines1, labels1 = ax1.get_legend_handles_labels()
    if 'power' in df.columns:
        lines2, labels2 = ax2.get_legend_handles_labels()
        ax1.legend(lines1 + lines2, labels1 + labels2, loc='upper right')
    else:
        ax1.legend(loc='upper right')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 10. Save Model

# %%
# Save the multi-channel model
model_mc.save('cnn_model_multichannel.keras')

# Save the scaler
import joblib
joblib.dump(scaler, 'cnn_scaler_multichannel.pkl')

# Save results to CSV
pd.DataFrame([{k: r[k] for k in ['athlete', 'session', 'f_beta', 'precision', 'recall', 'mean_error_sec', 'n_true', 'n_pred']}
             for r in results_mc]).to_csv('cnn_results_multichannel.csv', index=False)

print("✓ Saved: cnn_model_multichannel.keras, cnn_scaler_multichannel.pkl, cnn_results_multichannel.csv")
# Out:
# ✓ Saved: cnn_model_multichannel.keras, cnn_scaler_multichannel.pkl, cnn_results_multichannel.csv

# %%
# ok next steps:
# try the semantic grouping suggested by claude
# and check out the fast.ai thingy from richard
